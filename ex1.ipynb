# %%
while True:
    user_input = input("숫자를 입력하세요(종료는 q입력):")

    if user_input == "q":
        print("종료합니다.")
        break

print()
# Out:
# 종료합니다.

# %%
git pull origin main
# Out:
#   Cell In[1], line 1
#     git pull origin main
#         ^
# SyntaxError: invalid syntax
