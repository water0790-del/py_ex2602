# %%
#라이브러리 : 여러개의 모듈들을 묶어 특정 기능을 제공 하는 패키지 집합
# 여러 모듈 + 하위 패키지 구조
# 특정 목적을 위한 기능 모음
# 외부라이브러리
# 표준(내부)라이브러리

# %%
# 수학관련 모듈
# 수학관련 모듈
import math

print(math.sprt(16))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 6
#       1 # 수학관련 모듈
#       2 # 수학관련 모듈
#       3 #
#       4 import math
# ----> 6 print(math.sprt(16))
#
# AttributeError: module 'math' has no attribute 'sprt'

# %%
import random
print(random.randint(1, 100))
# Out:
# 100

# %%
import datetime
#현재 날짜와 시간 출력기능
print(datetime.datetime.now())
# Out:
# 2026-02-26 13:03:55.679641

# %%
#시간흐름을 제어/ 프로그램을 잠시 멈출때
import time
#프로그램을 3초가 멈추게 한다.
time.sleep(3)
#프로그램을 3초 지난후 실행
print("3초 후 실행")
# Out:
# 3ch gn tlfgod

# %%
#시스템오류
#번전확인, 프로그램 종료 사용
import sys
#현재 사용중인 파있너 버전을 출력
print(sys.version)
# Out:
# 3.14.3 (tags/v3.14.3:323c59a, Feb  3 2026, 16:04:56) [MSC v.1944 64 bit (AMD64)]

# %%
#운영체제 모듈

import os
#현재 작업중인 폴더 경로 출력

print(os.getcwd())
# Out:
# c:\work(장)\py_ex2602

# %%
#데이터 형식 모듈
#jsom : 데이터를 약속된 모양으로 적는 방식("key"' "value")
#웹, API, 파일 저장에 사용
#- API : 프로그램끼리 대화하는 방법(규칙)
import json

data = {"name": "jin", "age" : 20}
print(json.dumps(data))
# Out:
# {"name": "jin", "age": 20}

# %%
#정규(정규식)표현식 모듈
#문자열 패턴 검사 모듈
# 형식 확인(아이디, 이메일 등)에 사용
#

import re

print(bool(re.match("hi", "hi python")))
# Out:
# True

# %%
# csv 파일 모듈(엑셀) 파일을 읽고 쓰는 모듈
import csv
with open("test.csv", "w", newline="") as f:
    csv.writer(f).writerow(["nam", "score"])

# %%
# 자료구조 모듈
# 자료구조를 편하게 쓰도록 도와줌
# 카운트, 큐, 딕셔너리 확장 기능 제공

from collections import Counter

# 문자열에서 각 글자의 개수를 셈
print(Counter("apple"))
# Out:
# Counter({'p': 2, 'a': 1, 'l': 1, 'e': 1})
